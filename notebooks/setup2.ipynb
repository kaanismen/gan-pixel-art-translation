# %% [markdown]
# # 🔧 Colab Setup for img2img-turbo
# This notebook sets up your environment in one go.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/Shareddrives/justpalletteLoss/img2img-turbo
# Out:
# /content/drive/Shareddrives/justpalletteLoss/img2img-turbo

# %%
# !pip install lpips
# !pip install clean-fid
# !accelerate config default
# !pip install vision-aided-loss
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.8/53.8 kB 5.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 69.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 92.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 51.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 11.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 42.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 19.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 75.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
# !accelerate launch --num_processes 1 --num_machines 1 --mixed_precision fp16 --dynamo_backend no \
  /content/drive/Shareddrives/justpalletteLoss//img2img-turbo/src/train_cyclegan_turbo_final.py \
  --dataset_folder="/content/drive/Shareddrives/justpalletteLoss/img2img-turbo/data/dataset_pixel_art" \
  --train_img_prep="resize_128" \
  --val_img_prep="no_resize" \
  --output_dir="/content/drive/Shareddrives/justpalletteLoss/img2img-turbo/output/pixeltraining128_default" \
  --tracker_project_name="pixeltraining128_default" \
  --learning_rate="1e-5" \
  --max_train_steps=6000 \
  --train_batch_size=1 \
  --gradient_accumulation_steps=4 \
  --validation_steps=600 \
  --report_to="wandb" \
  --palette_loss="active" \
  --lambda_palette=0.0 \
  --lambda_gan 0.5 --lambda_idt 1 --lambda_cycle 1 \
  --gradient_checkpointing
# Out:
# 2025-05-27 10:01:49.742860: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-05-27 10:01:49.760619: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748340109.781812    4917 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748340109.788354    4917 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
pip install torch==2.6.0 torchvision==0.21.0 torchaudio==2.6.0 fastai --upgrade --force-reinstall
# Out:
# ...
#   Using cached torch-2.6.0-cp311-cp311-manylinux1_x86_64.whl.metadata (28 kB)
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# ...

# %%
# !sed -i 's/model\.unet\.enable_xformers_memory_efficient_attention()/# model.unet.enable_xformers_memory_efficient_attention()/g' /content/drive/Shareddrives/deneme/img2img-turbo/src/inference_unpaired.py

# %%
# !pip install lpips
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.8/53.8 kB 2.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 123.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 96.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 61.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 11.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 41.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 19.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 4.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 105.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
# !accelerate launch --num_processes 1 --num_machines 1 --mixed_precision fp16 --dynamo_backend no \
  /content/drive/Shareddrives/deneme/img2img-turbo/src/train_cyclegan_turbo.py \
  --dataset_folder="/content/drive/Shareddrives/deneme/img2img-turbo/data/dataset_pixel_art" \
  --train_img_prep="resize_256x256" \
  --val_img_prep="no_resize" \
  --image_edge="medium" \
  --output_dir="/content/drive/Shareddrives/deneme/img2img-turbo/output/256x256_model_medium_125_palette_loss_min_area_func" \
  --tracker_project_name="pixeltraining_medium_125_on_256x256_palette_loss_min_area_func" \
  --max_train_steps=3000 \
  --train_batch_size=1 \
  --gradient_accumulation_steps=4 \
  --validation_steps=300 \
  --report_to="wandb" \
  --palette_loss="active" \
  --lambda_palette=0.1 \
  --gradient_checkpointing
# Out:
# 2025-05-15 07:52:08.873306: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-05-15 07:52:08.889313: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1747295528.909800    4604 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1747295528.916390    4604 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !pip install lpips

# %%
# !ls /content/drive/Shareddrives/deneme/img2img-turbo/src/
# Out:
# cyclegan_turbo.py      model.py		 train_cyclegan_turbo.py
# image_prep.py	       my_utils		 train_pix2pix_turbo.py
# inference_paired.py    pix2pix_turbo.py
# inference_unpaired.py  __pycache__

# %%
# !pip install vision_aided_loss
# Out:
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 4.4 MB/s eta 0:00:00
# ...
#   Created wheel for gdown: filename=gdown-4.4.0-py3-none-any.whl size=14845 sha256=ff218f79aa0e7b4a259fa66578707892b7ce325e16a65e67be0bf0bfc1cf9a03
#   Stored in directory: /root/.cache/pip/wheels/04/17/f7/f9585b8ed11a19d05b50f0ab33aa6635a5179241b92982ab27
# Successfully built gdown
# ...
#   Attempting uninstall: gdown
#     Found existing installation: gdown 5.2.0
#     Uninstalling gdown-5.2.0:
#       Successfully uninstalled gdown-5.2.0
# ...

# %%
# !pip install clean-fid

# %%
# !python src/inference_unpaired.py \
  --model_path "output/pixeltraining5/checkpoints/model_1501.pkl" \
  --input_image "assets/examples/day2night_input.png" \
  --output_dir "outputs/day2night_output.png" \
  --direction a2b \
  --prompt "Convert photo to pixel art style"
# Out:
# 2025-05-18 06:42:40.315295: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-05-18 06:42:40.331371: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1747550560.349394    2885 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1747550560.354741    2885 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
from PIL import Image
import IPython.display as display

# Adjust the path as needed
input_path = "/content/drive/Shareddrives/edge/img2img-turbo/assets/examples/day2night_input.png"
output_path = "/content/drive/Shareddrives/edge/img2img-turbo/outputs/day2night_input.png"

# Load and display the image
img2 = Image.open(input_path)
display.display(img2)
img = Image.open(output_path)
display.display(img)
small = img.resize((256, 256),   resample=Image.BILINEAR)
pixelated = small.resize(img.size, resample=Image.NEAREST)
display.display(pixelated)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1280x720>
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1280x720>
# <PIL.Image.Image image mode=RGB size=1280x720>

# %%
import sys
sys.path.append("/content/drive/MyDrive/img2img-turbo/img2img-turbo/src")

# !pip install lpips
# !pip install clean-fid
# !accelerate config default
# !pip install vision-aided-loss
# Out:
# ...
# Configuration already exists at /root/.cache/huggingface/accelerate/default_config.yaml, will not override. Run `accelerate config` manually or pass a different `save_location`.
# ...

# %%
import os
os.environ["WANDB_MODE"] = "offline"

# %%
# !cd /content/drive/MyDrive/img2img-turbo/img2img-turbo && \
NCCL_P2P_DISABLE=1 accelerate launch --main_process_port 29501 src/train_cyclegan_turbo.py \
  --pretrained_model_name_or_path="stabilityai/sd-turbo" \
  --output_dir="output/cyclegan_turbo/my_horse2zebra" \
  --dataset_folder="data/my_horse2zebra" \
  --train_img_prep "resize_286_randomcrop_256x256_hflip" --val_img_prep "no_resize" \
  --learning_rate="1e-5" --max_train_steps=25000 \
  --train_batch_size=1 --gradient_accumulation_steps=1 \
  --report_to "wandb" \
  --tracker_project_name "gpanmar_unpaired_h2z_cycle_debug_v2" \
  --validation_steps 250 \
  --lambda_gan 0.5 --lambda_idt 1 --lambda_cycle 1
# Out:
# 2025-04-20 22:31:18.771797: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-04-20 22:31:18.789368: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745188278.811416   15189 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1745188278.818342   15189 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
import os
os.environ["WANDB_MODE"] = "offline"
# !accelerate launch --num_processes 1 --num_machines 1 --mixed_precision fp16 --dynamo_backend no /content/drive/Shareddrives/deneme/img2img-turbo/src/train_cyclegan_turbo.py \
  --dataset_folder="/content/drive/Shareddrives/deneme/img2img-turbo/data/dataset_pixel_art" \
  --train_img_prep="resize_128x128" \
  --val_img_prep="no_resize" \
  --output_dir="/content/drive/Shareddrives/deneme/img2img-turbo/output/128x128_model" \
  --tracker_project_name="pixeltraining128" \
  --report_to "wandb" \
  --max_train_steps=3000 \
  --train_batch_size=1 \
  --gradient_accumulation_steps=4 \
  --validation_steps=300 \
  --lambda_gan 0.5 --lambda_idt 1 --lambda_cycle 1
# Out:
# 2025-04-30 11:26:26.894437: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-04-30 11:26:26.912129: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746012386.933759    5288 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746012386.940171    5288 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...
